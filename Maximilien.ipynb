# %%
import pandas as pd

df_train = pd.read_parquet('Data/train.parquet')

# %%
# To do: 
# Split les colonnes datess en plusieurs colonnes (année, mois, jour, heure, sec)
# Gérer le fait qu'on est la même personne plusieurs fois

# %% [markdown]
# ### EDA

# %%
df_train.columns
# Out:
# Index(['status', 'gender', 'firstName', 'level', 'lastName', 'userId', 'ts',
#        'auth', 'page', 'sessionId', 'location', 'itemInSession', 'userAgent',
#        'method', 'length', 'song', 'artist', 'time', 'registration'],
#       dtype='object')

# %%
df_train
# Out:
#           status gender firstName level lastName   userId             ts  \
# 0            200      M     Shlok  paid  Johnson  1749042  1538352001000
# 992          200      M     Shlok  paid  Johnson  1749042  1538352525000
# 1360         200      M     Shlok  paid  Johnson  1749042  1538352703000
# 1825         200      M     Shlok  paid  Johnson  1749042  1538352935000
# 2366         200      M     Shlok  paid  Johnson  1749042  1538353200000
# ...          ...    ...       ...   ...      ...      ...            ...
# 25661184     200      M      Noah  paid  Bentley  1152881  1542671404000
# 25661214     200      M      Noah  paid  Bentley  1152881  1542671443000
# 25661320     200      M      Noah  paid  Bentley  1152881  1542671587000
# 25661462     200      M      Noah  paid  Bentley  1152881  1542671750000
# 25661583     200      M      Noah  paid  Bentley  1152881  1542671913000
#
#                auth         page  sessionId                         location  \
# ...

# %%
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17499636 entries, 0 to 25661583
# Data columns (total 19 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   status         int64
#  1   gender         object
#  2   firstName      object
#  3   level          object
#  4   lastName       object
#  5   userId         object
#  6   ts             int64
#  7   auth           object
#  8   page           object
#  9   sessionId      int64
#  10  location       object
#  11  itemInSession  int64
#  12  userAgent      object
#  13  method         object
#  14  length         float64
#  15  song           object
#  16  artist         object
#  17  time           datetime64[us]
#  18  registration   datetime64[us]
# dtypes: datetime64[us](2), float64(1), int64(4), object(12)
# memory usage: 2.6+ GB
# None
#               status    gender firstName     level  lastName    userId  \
# count   1.749964e+07  17499636  17499636  17499636  17499636  17499636
# ...

# %%
print(df_train.describe(include='all'))
# Out:
#               status    gender firstName     level  lastName    userId  \
# count   1.749964e+07  17499636  17499636  17499636  17499636  17499636
# unique           NaN         2      4967         2      1000     19140
# top              NaN         M  Isabella      paid     Smith   1931933
# freq             NaN   9191364    124230  13506659    373759     10998
# mean    2.091387e+02       NaN       NaN       NaN       NaN       NaN
# min     2.000000e+02       NaN       NaN       NaN       NaN       NaN
# 25%     2.000000e+02       NaN       NaN       NaN       NaN       NaN
# 50%     2.000000e+02       NaN       NaN       NaN       NaN       NaN
# 75%     2.000000e+02       NaN       NaN       NaN       NaN       NaN
# max     4.040000e+02       NaN       NaN       NaN       NaN       NaN
# std     3.023050e+01       NaN       NaN       NaN       NaN       NaN
#
#                   ts       auth      page     sessionId  \
# count   1.749964e+07   17499636  17499636  1.749964e+07
# ...
